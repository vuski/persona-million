# %% [markdown]
# # v4 비교 실험 — claude-haiku-4-5-20251001
#
# - 같은 100명에게 `voter_context_v4` + `system_prompt_v4` 적용
# - 페르소나 카드에 `[정치적 이해관계]` 블록 주입
# - 모델: `claude-haiku-4-5-20251001` (Anthropic Claude Haiku 4.5, 스냅샷 고정)
# - CSV 누적 시 `model = anthropic/claude-haiku-4-5-20251001`
# - 결과: `vote_results_all.csv` 누적, raw `response/`

# %%
# [Cell 1] imports & env
import os, json, time, re
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate

BASE = Path.cwd() if Path.cwd().name == "backend" else Path.cwd() / "backend"
CONTEXT_DIR = BASE / "context"
RESULTS_PATH = BASE / "vote_results_all.csv"
INTERESTS_PATH = BASE / "interests" / "personas_gpt-5.4-mini_all_interests.tsv"
RESPONSE_DIR = BASE / "response"
RESPONSE_DIR.mkdir(exist_ok=True)
LOG_DIR = BASE / "log"
LOG_DIR.mkdir(exist_ok=True)

MODEL = "claude-haiku-4-5-20251001"
PROVIDER = "anthropic"
VERSION = "v4"
MODEL_FULL = f"{PROVIDER}/{MODEL}"

# ANTHROPIC_API_KEY 는 backend/.env.local 또는 프로젝트 루트 .env.local 에서 로드
for env_path in [BASE / ".env.local", BASE.parent / ".env.local"]:
    if env_path.exists():
        load_dotenv(env_path)
        print(f"loaded: {env_path}")
        break
assert os.environ.get("ANTHROPIC_API_KEY"), "ANTHROPIC_API_KEY 필요"

def safe_filename(s: str) -> str:
    return re.sub(r"[^\w\-.]", "_", s)

print(f"model: {MODEL_FULL}, version: {VERSION}")
# Out:
# loaded: z:\Github\persona-million\.env.local
# model: anthropic/claude-haiku-4-5-20251001, version: v4

# %%
# [Cell 2] v2 + gpt-5.4-mini 페르소나 100명 로드 + political_interest 매핑
df_all = pd.read_csv(RESULTS_PATH, encoding="utf-8-sig")
mask = (df_all["model"] == "openai/gpt-5.4-mini") & (df_all["voter_context_version"] == "v2")
targets = df_all[mask].drop_duplicates(subset=["persona_uuid"]).reset_index(drop=True)
print(f"target personas: {len(targets)}")

interests = pd.read_csv(INTERESTS_PATH, sep="\t", encoding="utf-8-sig")[["persona_uuid", "political_interest"]]
print(f"interests rows: {len(interests)}")

targets = targets.merge(interests, on="persona_uuid", how="left")
missing = targets["political_interest"].isna().sum()
print(f"political_interest 누락: {missing}/{len(targets)}")

# 이미 (anthropic/haiku) × v4 처리된 uuid 는 건너뛰기
done = set(df_all[(df_all["model"] == MODEL_FULL) & (df_all["voter_context_version"] == VERSION)]["persona_uuid"].tolist())
todo = targets[~targets["persona_uuid"].isin(done)].reset_index(drop=True)
print(f"이미 처리됨: {len(done)}, 남은 작업: {len(todo)}")
# Out:
# target personas: 100
# interests rows: 100
# political_interest 누락: 0/100
# 이미 처리됨: 0, 남은 작업: 100

# %%
# [Cell 3] v4 프롬프트 + Anthropic 체인 + persona_card with political_interest
def load_context(version: str) -> str:
    return (CONTEXT_DIR / f"voter_context_{version}.md").read_text(encoding="utf-8")
def load_system_prompt(version: str) -> str:
    return (CONTEXT_DIR / f"system_prompt_{version}.md").read_text(encoding="utf-8")

POLITICAL_CONTEXT = load_context(VERSION)
SYSTEM_TEMPLATE = load_system_prompt(VERSION)
print(f"voter_context_{VERSION}.md: {len(POLITICAL_CONTEXT)} chars")
print(f"system_prompt_{VERSION}.md: {len(SYSTEM_TEMPLATE)} chars")

USER_TEMPLATE = """다음 페르소나가 2026년 6월 3일 지방선거(또는 가까운 미래의 총선·대선)에서 어느 정당을 지지·투표할지 추론하시오.

{persona_card}

JSON만 출력."""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_TEMPLATE),
    ("user", USER_TEMPLATE),
])

# Anthropic 은 OpenAI 의 response_format JSON mode 같은 게 없음 → 시스템 프롬프트의 JSON 강제 규칙에 의존
llm = ChatAnthropic(
    model=MODEL,
    temperature=0.7,
    max_tokens=1500,
)
chain = prompt | llm

VOTE_KEYS = ("vote", "party", "정당", "지지정당", "투표", "선택", "지지")
REASON_KEYS = ("reason", "이유", "rationale", "사유", "근거", "설명")

def _try_complete_json(s: str) -> str:
    last_close = s.rfind("}")
    last_open = s.rfind("{")
    if last_open == -1: return s
    if last_close > last_open: return s[last_open:last_close + 1]
    candidate = s[last_open:].rstrip().rstrip(",")
    if candidate.count('"') % 2 == 1: candidate += '"'
    candidate += "}"
    return candidate

def parse_response(raw: str) -> dict:
    s = re.sub(r"<think>.*?</think>", "", raw, flags=re.DOTALL)
    s = re.sub(r"```(?:json)?\s*", "", s).replace("```", "")
    m = re.search(r"\{.*\}", s, flags=re.DOTALL)
    if m:
        try: return json.loads(m.group(0))
        except json.JSONDecodeError: pass
    try: return json.loads(_try_complete_json(s))
    except json.JSONDecodeError:
        raise ValueError(f"no parseable JSON: {raw[:200]!r}")

def pick(d, keys):
    for k in keys:
        v = d.get(k)
        if v: return v
    return None

def persona_card(r) -> str:
    fields = [
        ("성별", r["sex"]), ("연령", f"{r['age']}세"),
        ("혼인상태", r["marital_status"]),
        ("가구형태", r["family_type"]), ("주거", r["housing_type"]),
        ("학력", r["education_level"]), ("전공", r["bachelors_field"]),
        ("직업", r["occupation"]),
        ("지역", f"{r['province']} {r['district']}"),
    ]
    demo = "\n".join(f"- {k}: {v}" for k, v in fields if v)
    narr = (
        f"[요약]\n{r['persona_summary']}\n\n"
        f"[직업적 면모]\n{r['professional_persona']}\n\n"
        f"[가족 면모]\n{r['family_persona']}\n\n"
        f"[문화적 배경]\n{r['cultural_background']}\n\n"
        f"[관심사]\n{r['hobbies_and_interests']}\n\n"
        f"[목표]\n{r['career_goals_and_ambitions']}"
    )
    out = f"## 인구통계\n{demo}\n\n## 인물 서사\n{narr}"
    pi = r.get("political_interest")
    if isinstance(pi, str) and pi.strip():
        out += f"\n\n## 정치적 이해관계\n[정치적 이해관계]\n{pi.strip()}"
    return out

if len(todo) > 0:
    print("\n--- 첫 페르소나 카드 미리보기 ---")
    print(persona_card(todo.iloc[0])[:1200])
# Out:
# voter_context_v4.md: 2590 chars
# system_prompt_v4.md: 1181 chars
#
# --- 첫 페르소나 카드 미리보기 ---
# ## 인구통계
# - 성별: 여자
# - 연령: 79세
# - 혼인상태: 배우자있음
# - 가구형태: 배우자와 거주
# - 주거: 단독주택
# - 학력: 초등학교
# - 전공: 해당없음
# - 직업: 건물 청소원
# - 지역: 충청남 충청남-금산군
#
# ## 인물 서사
# [요약]
# 장말순 씨는 금산 보건소의 보이지 않는 곳을 묵묵히 가꾸며, 소박한 노동과 정겨운 이웃 관계 속에서 삶의 안정을 찾는 79세의 강단 있는 할머니입니다.
#
# [직업적 면모]
# 장말순 씨는 금산군 보건소 복도의 찌든 때를 없애기 위해 락스와 세제를 자신만의 비율로 섞어 사용하며, 내원객들이 붐비는 시간대를 피해 소리 없이 빠르게 바닥을 닦아내는 능숙한 청소원입니다.
#
# [가족 면모]
# 장말순 씨는 금산의 낡은 단독주택에서 무뚝뚝하지만 평생 곁을 지켜준 남편과 함께 살며, 서로의 존재만으로도 충분한 고요하고 안정적인 노후를 보내고 있습니다.
#
# [문화적 배경]
# 충남 금산의 인삼 밭이 내려다보이는 마을에서 나고 자라며 흙과 함께 유년 시절을 보냈습니다. 정규 교육은 짧았지만, 마을 공동체 안에서 서로 돕고 나누는 정서와 금산 특유의 느긋하면서도 강단 있는 생활 방식을 몸에 익혔습니다.
#
# [관심사]
# 금강변 산책로를 천천히 걸으며 계절마다 변하는 풍경을 구경하거나, 동네 친구들과 함께 읍내 목욕탕에서 뜨끈한 물에 몸을 지지며 밀린 이야기를 나누는 시간을 보냅니다.
#
# [목표]
# 몸이 허락하는 한 지금 하는 청소 일을 계속 유지하며, 매달 받는 월급으로 남편과 함께 가끔 외식을 즐기고 소소한 생활비를 보태는 안정적인 일상을 유지하고자 합니다.
#
# ## 정치적 이해관계
# [정치적 이해관계]
# 올해 일흔아홉, 금산군 보건소에서 "락스와 세제를 자신만의 비율로 섞어" 복도를 닦고 있다. 새벽에 라디오를 틀면 2026년 기초연금이 단독가구 월 40만 원까지 오른다, 선정기준액이 247만 원으로 높아졌다는 얘기가 자주 나온다. 우리 영감이랑 둘이 사는 이 낡은 단독주택에서 그 돈이 얼마나 큰지 사람들은 모른다. 영감 약값에 보태고, "두 주에 한 번 배달로 시켜 먹는 단팥빵" 값도 거기서 나온다.  요즘 진짜 무서운 건 보건소 의사 자리가 자꾸 빈다는 거다. 내가 닦는 그 복도 끝 진료실에 공보의가 안 온단다. 읍면 보건지소 미배치율이 2026년 82%까지 올라간다는 뉴스를 듣고 영감이랑 한참을 한숨 쉬었다. 금산 같은 데서 의사 없으면 노인들은 어디로 가나. 대전까지 버스 타고 가야 하는데 농어촌버스도 줄고,

# %%
# [Cell 3.5] 1명만 호출해서 응답·파싱·시간 확인 (스모크 테스트)
if len(todo) > 0:
    r = todo.iloc[0]
    t0 = time.perf_counter()
    msg = chain.invoke({"political_context": POLITICAL_CONTEXT, "persona_card": persona_card(r)})
    el = time.perf_counter() - t0
    raw = msg.content if hasattr(msg, "content") else str(msg)
    print(f"[elapsed] {el:.2f}s\n")
    print("--- raw ---")
    print(raw)
    print("\n--- parsed ---")
    p = parse_response(raw)
    print("vote:", pick(p, VOTE_KEYS))
    print("reason:", pick(p, REASON_KEYS))
# Out:
# [elapsed] 6.19s
#
# --- raw ---
# ```json
# {"vote": "더불어민주당", "reason": "기초연금 인상이 우리 생활을 직접 바꿨어요. 월 40만 원, 선정기준액 247만 원—그 돈이 영감 약값과 한 달에 한두 번 사 먹는 단팥빵, 삼겹살 외식으로 이어지는 거거든요. 79세까지 보건소에서 청소일을 하면서 느낀 가장 큰 두려움은 의료 접근성이에요. 내가 닦는 진료실에 공보의가 안 오고, 읍면 보건지소 미배치율이 82%까지 올라간다니—금산 같은 곳 노인들은 대전까지 버스 타고 가야 하는데 농어촌버스도 자꾸 줄어들잖아요. 현 정부가 기초연금을 올려준 건 사실이고, 노인일자리도 역대 최대라고 하니까요. 최저임금도 올랐고요. 물론 용역 청소원인 우리한테 그게 고스란히 반영될지는 모르겠고, 인삼 농가 차광자재 지원 같은 건 내 일과 직접 상관없어요. 하지만 지금 이 정부가 농촌 노인 생활을 조금이라도 챙기려는 쪽이라고 봐요. 영감이랑 한 달에 한 번 삼겹살집 가는 게 내 목표인데, 그걸 지켜주는 정책이 현 정부 쪽에 더 있다고 느껴져요."}
# ```
#
# --- parsed ---
# vote: 더불어민주당
# reason: 기초연금 인상이 우리 생활을 직접 바꿨어요. 월 40만 원, 선정기준액 247만 원—그 돈이 영감 약값과 한 달에 한두 번 사 먹는 단팥빵, 삼겹살 외식으로 이어지는 거거든요. 79세까지 보건소에서 청소일을 하면서 느낀 가장 큰 두려움은 의료 접근성이에요. 내가 닦는 진료실에 공보의가 안 오고, 읍면 보건지소 미배치율이 82%까지 올라간다니—금산 같은 곳 노인들은 대전까지 버스 타고 가야 하는데 농어촌버스도 자꾸 줄어들잖아요. 현 정부가 기초연금을 올려준 건 사실이고, 노인일자리도 역대 최대라고 하니까요. 최저임금도 올랐고요. 물론 용역 청소원인 우리한테 그게 고스란히 반영될지는 모르겠고, 인삼 농가 차광자재 지원 같은 건 내 일과 직접 상관없어요. 하지만 지금 이 정부가 농촌 노인 생활을 조금이라도 챙기려는 쪽이라고 봐요. 영감이랑 한 달에 한 번 삼겹살집 가는 게 내 목표인데, 그걸 지켜주는 정책이 현 정부 쪽에 더 있다고 느껴져요.

# %%
# [Cell 4] 100명 v4 추론 (Haiku) → CSV 누적 + response/ 저장
log_path = LOG_DIR / f"{time.strftime('%Y%m%d-%H%M%S')}_voteV4_anthropic_{safe_filename(MODEL)}_{VERSION}.log"
log_f = log_path.open("w", encoding="utf-8")
def log(msg):
    print(msg, flush=True)
    log_f.write(msg + "\n"); log_f.flush()

log(f"=== {MODEL_FULL} × {len(todo)} (version={VERSION}) ===")
success = 0
for i, r in todo.iterrows():
    t0 = time.perf_counter()
    raw = ""
    try:
        msg = chain.invoke({"political_context": POLITICAL_CONTEXT, "persona_card": persona_card(r)})
        raw = msg.content if hasattr(msg, "content") else str(msg)
        p = parse_response(raw)
        vote = pick(p, VOTE_KEYS)
        reason = pick(p, REASON_KEYS)
        if not vote or not reason:
            raise ValueError(f"missing keys: {list(p.keys())}")
    except Exception as e:
        el = time.perf_counter() - t0
        log(f"[{i+1:>3}/{len(todo)}] ERROR ({el:.1f}s): {str(e)[:120]}")
        ts = time.strftime("%Y%m%d-%H%M%S")
        fname = f"FAIL_{ts}_anthropic_{safe_filename(MODEL)}_{r['persona_uuid'][:8]}_{VERSION}.txt"
        (RESPONSE_DIR / fname).write_text(
            f"=== ERROR: {e}\n=== MODEL: {MODEL_FULL}\n=== UUID: {r['persona_uuid']}\n\n{raw}",
            encoding="utf-8")
        continue
    el = time.perf_counter() - t0
    success += 1

    ts = time.strftime("%Y%m%d-%H%M%S")
    fname = f"{ts}_anthropic_{safe_filename(MODEL)}_{r['persona_uuid'][:8]}_{VERSION}_{VERSION}.json"
    out = {
        "timestamp": ts,
        "model": MODEL_FULL,
        "voter_context_version": VERSION,
        "system_prompt_version": VERSION,
        "persona_uuid": r["persona_uuid"],
        "elapsed_sec": round(el, 3),
        "persona": {
            "sex": r["sex"], "age": int(r["age"]),
            "marital_status": r["marital_status"],
            "family_type": r["family_type"],
            "housing_type": r["housing_type"],
            "education_level": r["education_level"],
            "bachelors_field": r["bachelors_field"],
            "occupation": r["occupation"],
            "province": r["province"], "district": r["district"],
            "persona_summary": r["persona_summary"],
        },
        "political_interest": r.get("political_interest"),
        "raw_response": raw,
        "parsed": {"vote": vote, "reason": reason},
    }
    (RESPONSE_DIR / fname).write_text(json.dumps(out, ensure_ascii=False, indent=2), encoding="utf-8")

    rec = {
        "persona_uuid": r["persona_uuid"],
        "sex": r["sex"], "age": int(r["age"]),
        "marital_status": r["marital_status"],
        "family_type": r["family_type"], "housing_type": r["housing_type"],
        "education_level": r["education_level"],
        "bachelors_field": r["bachelors_field"],
        "occupation": r["occupation"],
        "province": r["province"], "district": r["district"],
        "persona_summary": r["persona_summary"],
        "vote": vote, "reason": reason,
        "model": MODEL_FULL,
        "elapsed_sec": round(el, 3),
        "response_file": fname,
        "voter_context_version": VERSION,
        "system_prompt_version": VERSION,
        "professional_persona": r["professional_persona"],
        "sports_persona": r["sports_persona"],
        "arts_persona": r["arts_persona"],
        "travel_persona": r["travel_persona"],
        "culinary_persona": r["culinary_persona"],
        "family_persona": r["family_persona"],
        "cultural_background": r["cultural_background"],
        "skills_and_expertise": r["skills_and_expertise"],
        "hobbies_and_interests": r["hobbies_and_interests"],
        "career_goals_and_ambitions": r["career_goals_and_ambitions"],
    }
    df_rec = pd.DataFrame([rec])
    if RESULTS_PATH.exists():
        df_rec.to_csv(RESULTS_PATH, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_rec.to_csv(RESULTS_PATH, index=False, encoding="utf-8-sig")
    log(f"[{i+1:>3}/{len(todo)}] {r['sex']} {r['age']}세 {r['province']:<6} "
        f"{str(r['occupation'])[:14]:<14} → {vote[:10]:<10} ({el:.1f}s)")

log(f"\n결과: {success}/{len(todo)} 성공")
log_f.close()
# Out:
# === anthropic/claude-haiku-4-5-20251001 × 100 (version=v4) ===
# [  1/100] 여자 79세 충청남    건물 청소원         → 더불어민주당     (4.6s)
# [  2/100] 남자 29세 대구     무직             → 무당층/기권     (5.7s)
# [  3/100] 남자 27세 서울     전직 금속제품 생산 관리자 → 무당층/기권     (4.7s)
# [  4/100] 여자 71세 대전     무직             → 더불어민주당     (4.4s)
# [  5/100] 여자 52세 부산     전동차 정비원        → 더불어민주당     (4.6s)
# [  6/100] 여자 20세 서울     무직             → 무당층/기권     (4.8s)
# [  7/100] 여자 26세 제주     초등학교 교사        → 더불어민주당     (5.2s)
# [  8/100] 남자 45세 경상남    용접기 조작원        → 국민의힘       (4.8s)
# [  9/100] 여자 63세 충청북    요양 보호사         → 더불어민주당     (5.1s)
# [ 10/100] 여자 67세 경기     무직             → 더불어민주당     (4.6s)
# [ 11/100] 여자 40세 강원     혼례 종사원         → 무당층/기권     (3.8s)
# [ 12/100] 남자 48세 서울     마케팅 전문가        → 무당층/기권     (4.3s)
# [ 13/100] 남자 45세 인천     그 외 택배원        → 더불어민주당     (6.9s)
# [ 14/100] 남자 38세 충청남    한식 조리사         → 더불어민주당     (4.9s)
# [ 15/100] 여자 26세 서울     보육교사           → 더불어민주당     (5.4s)
# [ 16/100] 남자 53세 부산     대형 화물차 운전원     → 무당층/기권     (4.6s)
# [ 17/100] 남자 36세 경기     사무 보조원         → 무당층/기권     (8.2s)
# [ 18/100] 여자 60세 전라남    그 외 건축 도장공     → 무당층/기권     (5.1s)
# [ 19/100] 남자 45세 경상북    계기 검침원         → 국민의힘       (4.7s)
# [ 20/100] 남자 69세 부산     인조석 설치원        → 무당층/기권     (5.2s)
# [ 21/100] 남자 31세 세종     병무행정 사무원       → 무당층/기권     (5.2s)
# [ 22/100] 여자 54세 전라남    관광버스 운전원       → 더불어민주당     (5.1s)
# [ 23/100] 여자 56세 경기     그 외 제도사        → 무당층/기권     (4.9s)
# [ 24/100] 여자 23세 서울     경리 사무원         → 더불어민주당     (5.1s)
# [ 25/100] 여자 52세 충청북    일반 비서          → 국민의힘       (4.7s)
# [ 26/100] 남자 20세 경기     무직             → 무당층/기권     (5.3s)
# [ 27/100] 여자 80세 인천     건물 청소원         → 더불어민주당     (4.2s)
# [ 28/100] 여자 57세 경기     지게차 운전원        → 더불어민주당     (5.3s)
# [ 29/100] 남자 26세 인천     무직             → 무당층/기권     (4.6s)
# [ 30/100] 남자 46세 경기     방수공            → 국민의힘       (5.5s)
# [ 31/100] 여자 23세 경기     무직             → 무당층/기권     (7.5s)
# [ 32/100] 남자 75세 부산     무직             → 더불어민주당     (5.1s)
# [ 33/100] 남자 48세 서울     무직             → 더불어민주당     (4.9s)
# [ 34/100] 여자 48세 서울     무직             → 더불어민주당     (4.7s)
# [ 35/100] 남자 34세 광주     전자제품 개발 기술자 및  → 무당층/기권     (9.6s)
# [ 36/100] 여자 43세 부산     금형원            → 무당층/기권     (5.0s)
# [ 37/100] 여자 35세 경기     무직             → 무당층/기권     (9.0s)
# [ 38/100] 남자 42세 서울     무직             → 무당층/기권     (5.3s)
# [ 39/100] 여자 65세 서울     그 외 철도 및 전동차 기 → 더불어민주당     (4.5s)
# [ 40/100] 남자 46세 경기     해병대 부사관        → 더불어민주당     (5.2s)
# [ 41/100] 여자 51세 경상북    수동 포장원         → 무당층/기권     (5.0s)
# [ 42/100] 여자 47세 서울     주방 보조원         → 더불어민주당     (5.4s)
# [ 43/100] 남자 91세 대전     무직             → 무당층/기권     (4.6s)
# [ 44/100] 남자 64세 부산     무직             → 더불어민주당     (4.7s)
# [ 45/100] 여자 27세 전북     소방시설 공사 기술자 및  → 무당층/기권     (4.7s)
# [ 46/100] 여자 57세 경상남    일반 비서          → 무당층/기권     (5.1s)
# [ 47/100] 남자 64세 충청남    무직             → 무당층/기권     (6.1s)
# [ 48/100] 남자 60세 경기     전직 변호사, 현재 구직중 → 국민의힘       (5.2s)
# [ 49/100] 여자 19세 경상북    무직             → 무당층/기권     (5.3s)
# [ 50/100] 남자 63세 인천     무직             → 무당층/기권     (5.5s)
# [ 51/100] 남자 56세 경기     엘리베이터 설치 및 정비원 → 더불어민주당     (4.7s)
# [ 52/100] 여자 52세 경기     노인 및 장애인 돌봄 서비 → 더불어민주당     (8.0s)
# [ 53/100] 남자 33세 부산     무직             → 더불어민주당     (4.3s)
# [ 54/100] 여자 68세 경기     건물 청소원         → 더불어민주당     (9.8s)
# [ 55/100] 남자 47세 전북     건물 경비원         → 무당층/기권     (4.4s)
# [ 56/100] 남자 64세 경기     크레인 운전원        → 국민의힘       (5.5s)
# [ 57/100] 남자 28세 부산     판매 사무원         → 더불어민주당     (9.1s)
# [ 58/100] 남자 63세 경상북    무직             → 더불어민주당     (4.2s)
# [ 59/100] 여자 29세 경기     무직             → 무당층/기권     (8.4s)
# [ 60/100] 남자 27세 서울     무직             → 무당층/기권     (4.4s)
# [ 61/100] 여자 64세 경기     무직             → 더불어민주당     (8.5s)
# [ 62/100] 여자 53세 경기     가사 도우미         → 더불어민주당     (5.4s)
# [ 63/100] 여자 26세 경기     보육교사           → 더불어민주당     (4.8s)
# [ 64/100] 여자 19세 대구     무직             → 무당층/기권     (10.3s)
# [ 65/100] 여자 47세 대구     무직             → 무당층/기권     (4.8s)
# [ 66/100] 여자 70세 강원     무직             → 더불어민주당     (4.5s)
# [ 67/100] 남자 32세 인천     산업 안전원         → 더불어민주당     (4.7s)
# [ 68/100] 여자 40세 서울     웹 디자이너         → 무당층/기권     (10.0s)
# [ 69/100] 남자 24세 경상남    경리 사무원         → 무당층/기권     (4.9s)
# [ 70/100] 여자 51세 경기     무직             → 더불어민주당     (5.0s)
# [ 71/100] 남자 69세 경상남    무직             → 더불어민주당     (8.4s)
# [ 72/100] 남자 59세 대구     잠수 기능원         → 더불어민주당     (4.6s)
# [ 73/100] 남자 59세 충청남    무직             → 더불어민주당     (9.4s)
# [ 74/100] 남자 74세 대구     무직             → 무당층/기권     (5.1s)
# [ 75/100] 여자 60세 충청북    무직             → 더불어민주당     (4.0s)
# [ 76/100] 여자 73세 경기     무직             → 무당층/기권     (9.5s)
# [ 77/100] 남자 49세 서울     그 외 상점 판매원     → 무당층/기권     (4.7s)
# [ 78/100] 남자 76세 부산     무직             → 더불어민주당     (7.5s)
# [ 79/100] 남자 54세 경기     무직             → 더불어민주당     (4.8s)
# [ 80/100] 여자 40세 경기     무직             → 더불어민주당     (5.4s)
# [ 81/100] 남자 51세 전라남    무직             → 무당층/기권     (12.2s)
# [ 82/100] 여자 23세 부산     보육교사           → 더불어민주당     (5.5s)
# [ 83/100] 남자 61세 전라남    무직             → 더불어민주당     (5.1s)
# [ 84/100] 여자 68세 부산     무직             → 더불어민주당     (4.3s)
# [ 85/100] 여자 72세 대전     무직             → 더불어민주당     (4.3s)
# [ 86/100] 남자 39세 서울     정보 보안 전문가      → 무당층/기권     (9.3s)
# [ 87/100] 남자 50세 광주     출판 및 자료편집 사무원  → 무당층/기권     (4.9s)
# [ 88/100] 남자 57세 경기     금형원            → 국민의힘       (6.3s)
# [ 89/100] 남자 78세 경상북    무직             → 국민의힘       (7.1s)
# [ 90/100] 남자 44세 경기     회계 사무원         → 무당층/기권     (4.9s)
# [ 91/100] 여자 36세 광주     일반 간호사         → 더불어민주당     (9.5s)
# [ 92/100] 여자 41세 서울     전직 학습지 방문강사, 현 → 더불어민주당     (5.7s)
# [ 93/100] 남자 39세 서울     생산관리 사무원       → 더불어민주당     (6.3s)
# [ 94/100] 여자 59세 경기     무직             → 무당층/기권     (5.6s)
# [ 95/100] 여자 65세 서울     시설 경비원         → 더불어민주당     (5.2s)
# [ 96/100] 남자 43세 서울     시설 경비원         → 더불어민주당     (9.9s)
# [ 97/100] 남자 58세 제주     철도 기관사         → 더불어민주당     (4.4s)
# [ 98/100] 여자 51세 서울     무직             → 더불어민주당     (5.1s)
# [ 99/100] 여자 19세 경기     무직             → 무당층/기권     (9.7s)
# [100/100] 남자 59세 경상북    전기 및 전자 장비 제도사 → 국민의힘       (6.2s)
#
# 결과: 100/100 성공

# %%
# [Cell 5] 모델·버전 분포 비교 (gpt v2/v3/v4 + haiku v4)
df_all = pd.read_csv(RESULTS_PATH, encoding="utf-8-sig")
combos = [
    ("openai/gpt-5.4-mini", "v2"),
    ("openai/gpt-5.4-mini", "v3"),
    ("openai/gpt-5.4-mini", "v4"),
    (MODEL_FULL, "v4"),
]
for m, v in combos:
    sub = df_all[(df_all["model"] == m) & (df_all["voter_context_version"] == v)]
    sub = sub.drop_duplicates("persona_uuid", keep="last")
    if len(sub) == 0:
        continue
    print(f"=== {m} / {v} (n={len(sub)}) ===")
    print(sub["vote"].value_counts())
    print()
# Out:
# === openai/gpt-5.4-mini / v2 (n=100) ===
# vote
# 국민의힘      42
# 더불어민주당    40
# 무당층/기권    10
# 개혁신당       8
# Name: count, dtype: int64
#
# === openai/gpt-5.4-mini / v3 (n=100) ===
# vote
# 더불어민주당    49
# 국민의힘      37
# 개혁신당       9
# 무당층/기권     5
# Name: count, dtype: int64
#
# === openai/gpt-5.4-mini / v4 (n=100) ===
# vote
# 더불어민주당    79
# 국민의힘      11
# 개혁신당       8
# 진보당        1
# 무당층/기권     1
# Name: count, dtype: int64
#
# === anthropic/claude-haiku-4-5-20251001 / v4 (n=100) ===
# vote
# 더불어민주당    50
# 무당층/기권    41
# 국민의힘       9
# Name: count, dtype: int64
